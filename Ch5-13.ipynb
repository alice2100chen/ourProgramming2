# %%
num_visitors = [50, 10, 14, 7, 25, 30, 70]

# %%
print('星期日：', num_visitors[0], '人')
print('星期一：', num_visitors[1], '人')
print('星期二：', num_visitors[2], '人')
print('星期三：', num_visitors[3], '人')
print('星期四：', num_visitors[4], '人')
print('星期五：', num_visitors[5], '人')
print('星期六：', num_visitors[6], '人')
# Out:
# 星期日： 50 人
# 星期一： 10 人
# 星期二： 14 人
# 星期三： 7 人
# 星期四： 25 人
# 星期五： 30 人
# 星期六： 70 人
