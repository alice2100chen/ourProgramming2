# %% [markdown]
# 假設我們有三位學生的國文、數學與自然成績（如下表），
#
#
# 現在請利用Python程式雙層for迴圈，計算每個人的總成績（三個科目的總和），並顯示在電腦螢幕上（如下圖）。

# %%
grades = [[100, 20, 85],[95,99,75],[89,73,92]]
names = ['嘉明', '小美', '阿雄']

for i in range(3):
    sum = 0
    for j in range(3):
        sum += grades[i][j]
    print(names[i], '總分為', sum, '分')
# Out:
# 嘉明 總分為 205 分
# 小美 總分為 269 分
# 阿雄 總分為 254 分
