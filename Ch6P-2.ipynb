# %%
data=[5,7,2,9]
print(data)
# Out:
# [5, 7, 2, 9]

# %%
#示範排序函數 sorted()
print(sorted(data))
# Out:
# [2, 5, 7, 9]

# %%
# 示範搜尋函數 index()
# index()會回傳「搜尋的值位於list的索引值」
print(data.index(9))
# Out:
# 3
