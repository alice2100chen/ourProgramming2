# %% [markdown]
# 嘉明參加鐵人三項競賽，奪得冠軍，他的比賽成績如下表，
# ![替代文字](https://)
# 請利用Python程式將嘉明的「比賽項目名稱：成績」，顯示在電腦螢幕上，最終成果如下圖。

# %%
contest_names = ['游泳', '單車', '跑步']
times = ['30分鐘', '1小時', '1小時半']
for i in range(3):
    print(contest_names[i], ':', times[i])
# Out:
# 游泳 : 30分鐘
# 單車 : 1小時
# 跑步 : 1小時半
