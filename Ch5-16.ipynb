# %%
num_visitors = [50, 10, 14, 7, 25, 30, 70]
day_names = ['星期日：', '星期一：', '星期二：', '星期三：', '星期四：', 
             '星期五：', '星期六：']

# %%
for day_index in range(7):
    print(day_names[day_index], num_visitors[day_index], '人')
# Out:
# 星期日： 50 人
# 星期一： 10 人
# 星期二： 14 人
# 星期三： 7 人
# 星期四： 25 人
# 星期五： 30 人
# 星期六： 70 人
