# %%
s_chinese = int(input('請輸入國文分數:'))
s_english = int(input('請輸入英文分數:'))
s_math = int(input('請輸入數學分數:'))
s_avg = (s_chinese + s_english + s_math)/3
print('平均分數為:',s_avg)
# Out:
# 請輸入國文分數:92
# 請輸入英文分數:94
# 請輸入數學分數:90
# 平均分數為: 92.0
