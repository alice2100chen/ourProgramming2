# %%
score_array = [95, 92, 88, 96]       # 陣列中有4個元素

# %%
# for迴圈會執行 print() 4次，因為[0,1,2,3]中有4個元素
# i在每一回合的值分別是0, 1, 2, 3
for i in [0,1,2,3]:                 # 注意，這一列最後要加上「:」
    print(score_array[i])           # 這一列一定要縮排
# Out:
# 95
# 92
# 88
# 96
